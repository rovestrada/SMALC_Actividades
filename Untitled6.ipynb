# %% [markdown]
# <a href="https://colab.research.google.com/github/rovestrada/SMALC_Actividades/blob/act%2FTierra6Nuclear/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('image.jpg')
cv2_imshow(image)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print(image_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=640x596>
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

_, theresholded = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)

cv2_imshow(theresholded)
# Out:
# <PIL.Image.Image image mode=L size=419x402>

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('image.jpg', cv2.IMREAD_GRAYSCALE)

edges = cv2.Canny(image, 15,  200)

cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=3000x4000>
